# %% [markdown]
# ## Pandas Essencial
#
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)**
# xavecoding: https://youtube.com/c/xavecoding
#
# ![image.png](attachment:image.png)
# This work is licensed under a [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License](http://creativecommons.org/licenses/by-nc-sa/4.0/).

# %% [markdown]
# # Sumário
#
# - [1. Manipulação básica de Datasets](#1-manipulação-básica-de-datasets)
#     - [1.1 Importando o Data Set](#11-importando-o-dataset)
#     - [1.2 Exibindo as primeiras linhas do Data Set](#12-exibindo-as-primeiras-linhas-do-dataset)
#     - [1.3 Informações do Data Set e elementos chave](#13-informações-do-dataset-e-elementos-chave)
#         - [1.3.1 Informações Gerais sobre o Data Set](#131-informações-gerais-sobre-o-dataset)
#         - [1.3.2 Data Frame](#132-data-frame)
#             - [Criando um Data Frame](#criando-um-dataframe)
#             - [Renomeando as colunas de um Data Frame](#renomeando-as-colunas-de-um-dataframe)

# %% [markdown]
# ### Pacotes usados neste notebook

# %%
# pacotes usados neste notebook
import pandas as pd

# %% [markdown]
# # Manipulação de Dados com Pandas
# ***
# ## 1. Manipulação básica de Datasets
# ***
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/datasets/matheusfreitag/gas-prices-in-brazil
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos 2004 e 2019**. Cada observação (registro/linha) consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade no Brasil. Alguns dos princípais atributos (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
# \* O arquivo disponibilizado no Kaggle está no formato *tsv*. Embora o *pandas* consiga abrí-lo normalmente, converteu-se tal arquivo para o formato *CSV*, que é um dos formatos mais utilizados, e mudou-se seu separado para ";", apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ### 1.1 Importando o Dataset
#
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas. Por padrão, ela considera ',' como separador.

# %%
data = pd.read_csv('.\datasets\GasPricesinBrazil_2004-2019.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\ariel.asilva2\AppData\Local\Temp\ipykernel_20988\2465217227.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data = pd.read_csv('.\datasets\GasPricesinBrazil_2004-2019.csv')

# %%
data
# Out:
#        Unnamed: 0;DATA INICIAL;DATA FINAL;REGIÃO;ESTADO;PRODUTO;NÚMERO DE POSTOS PESQUISADOS;UNIDADE DE MEDIDA;PREÇO MÉDIO REVENDA;DESVIO PADRÃO REVENDA;PREÇO MÍNIMO REVENDA;PREÇO MÁXIMO REVENDA;MARGEM MÉDIA REVENDA;COEF DE VARIAÇÃO REVENDA;PREÇO MÉDIO DISTRIBUIÇÃO;DESVIO PADRÃO DISTRIBUIÇÃO;PREÇO MÍNIMO DISTRIBUIÇÃO;PREÇO MÁXIMO DISTRIBUIÇÃO;COEF DE VARIAÇÃO DISTRIBUIÇÃO;MÊS;ANO
# 0       0;2004-05-09;2004-05-15;CENTRO OESTE;DISTRITO ...
# 1       1;2004-05-09;2004-05-15;CENTRO OESTE;GOIAS;ETA...
# 2       2;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 3       3;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 4       4;2004-05-09;2004-05-15;NORDESTE;ALAGOAS;ETANO...
# ...                                                   ...
# 106818  106818;2019-06-23;2019-06-29;NORDESTE;RIO GRAN...
# 106819  106819;2019-06-23;2019-06-29;SUL;RIO GRANDE DO...
# 106820  106820;2019-06-23;2019-06-29;SUL;SANTA CATARIN...
# 106821  106821;2019-06-23;2019-06-29;SUDESTE;SAO PAULO...
# ...

# %% [markdown]
# O dataset não foi carregado corretamente pois o separador utilizado no arquivo CSV era ";" e não ",".
#
# Vamos carregá-lo então corretamente:

# %%
# carregando o dataset corretamente ==> neste caso, usa o separador ';'
data = pd.read_csv('.\datasets\GasPricesinBrazil_2004-2019.csv', sep=';')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\ariel.asilva2\AppData\Local\Temp\ipykernel_20988\3180146197.py:2: SyntaxWarning: invalid escape sequence '\d'
#   data = pd.read_csv('.\datasets\GasPricesinBrazil_2004-2019.csv', sep=';')

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %% [markdown]
# ## 1.2 Exibindo as primeiras linhas do DataSet
#
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
# exibe as 10 primeiras linhas do dataframe
data.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ## 1.3 Informações do Dataset e Elementos Chave
#
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %% [markdown]
# A primeira coluna da tabela, *Unnamed: 0*, parece não significar nada. Na verdade, ela parece ser os **índices** da tabela, que foram salvos como uma coluna. Veremos jajá como **remover tal coluna**.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (*null*), uma vez que o número de registro do dataframe e os números de valores *non-null* é de **106823**.
#
# Porém, veremos que não é bem assim para esse caso.
#
# Além disso, note que alguns atributos/colunas, por ex., 'PREÇO MÉDIOI DISTRIBUIÇÃO', possui tipo de dado `object` ao invés de `float`. Esse `object`, no geral, representa strings. Veremos se isso é problemático mais pra frente.

# %% [markdown]
# ### 1.3.2 Data Frame
#
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos (diferentes).

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo .shape do Data Frame.

# %%
data.shape # retorna uma tupla
# Out:
# (106823, 21)

# %%
print(f'O DataFrame possui {data.shape[0]} linhas/registros/observações e {data.shape[1]} colunas/atributos.')
# Out:
# O DataFrame possui 106823 linhas/registros/observações e 21 colunas/atributos.

# %% [markdown]
# ### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um *dicionário*, onde cada **chave** possui uma **lista de elementos de igual tamanho**. As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
personagens_df = pd.DataFrame({
    'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade': [16, 1000, 70],
    'peso': [70 ,15 , 60],
    'eh jedi': [True, True, False] # o nome da coluna pode ter espaços
})

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
personagens_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      int64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 207.0+ bytes

# %% [markdown]
# ### **VEJA MAIS**
#
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# ### **Renomeando as colunas de um DataFrame**
#
# ==> O atributo `DataFrame.columns` retorna uma ";lista" com os **nomes de todas as colunas** do data frame.

# %%
personagens_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='object')

# %%
type(personagens_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(personagens_df.columns)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# ==> Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma *cópia* do data frame com as colunas renomeadas:

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
personagens_df_renomeado = personagens_df.rename(columns={
    'nome' : 'Nome Completo', # renomeia a coluna de nome 'nome' para 'Nome Completo'
    'idade' : 'Idade'
})

# %%
personagens_df_renomeado
# Out:
#     Nome Completo  Idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# Para renomear o próprio data frame em questão, utilize o parâmetro `inplace=True`:

# %%
personagens_df.rename(columns={'nome' : 'Nome Completo', 'idade' : 'Idade'}, inplace=True)

# %%
personagens_df
# Out:
#     Nome Completo  Idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# ==> Uma outra forma de **renomear todas as colunas** de um data frame é passar uma lista com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %%
personagens_df.columns
# Out:
# Index(['Nome Completo', 'Idade', 'peso', 'eh jedi'], dtype='object')

# %%
personagens_df.columns = ['NOME', 'IDADE', 'PESO', 'EH JEDI']

# %%
personagens_df
# Out:
#              NOME  IDADE  PESO  EH JEDI
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# ### 1.3.3 Series
#
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
# selecionando uma coluna inteira
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# selecionando uma coluna inteira
# esta forma só funciona para colunas com nomes sem espaços, acentos, etc. (caracteres inválidos)
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
type(data['ESTADO'])
# Out:
# pandas.core.series.Series

# %%
# selecionando a observação indexada no índice [1] do dataframe
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %%
type(data.iloc[1])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([5.5, 6.0, 9.5])
# Out:
# 0    5.5
# 1    6.0
# 2    9.5
# dtype: float64

# %% [markdown]
# Podemos ainda alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa)

# %%
pd.Series([5.5, 6.0, 9.5], index=['prova 1', 'prova 2', 'prova 3'], name='Notas do Luke Skywalker')
# Out:
# prova 1    5.5
# prova 2    6.0
# prova 3    9.5
# Name: Notas do Luke Skywalker, dtype: float64

# %% [markdown]
# ### **VEJA MAIS**
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html

# %% [markdown]
# ### 1.3.4 Atribuindo Dados
#
# #### 1.3.4.1 Atribuindo constantes

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
produto_view = data['PRODUTO'] # a series retornada referente à coluna, NÃO É UMA CÓPIA, mas sim, uma REFERÊNCIA à coluna do dataframe
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copy_bkp = data['PRODUTO'].copy() # retorna uma cópia da coluna 'PRODUTO'
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
data['PRODUTO'] = 'Combustível' # atribuindo o valor constante 'Combustível' para cada linha do dataframe na coluna 'PRODUTO'

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Combustível                           127              R$/l
# 1  Combustível                           387              R$/l
# 2  Combustível                           192              R$/l
# 3  Combustível                           162              R$/l
# 4  Combustível                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
nrows, ncols = data.shape
nrows, ncols
# Out:
# (106823, 21)

# %%
novos_produtos = [ f'Produto {i}' for i in range(nrows)]
len(novos_produtos)
# Out:
# 106823

# %%
# a quantidade de elementos da lista 'novos produtos' é igual ao número de linhas do dataframe
data['PRODUTO'] = novos_produtos

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#      PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Produto 0                           127              R$/l
# 1  Produto 1                           387              R$/l
# 2  Produto 2                           192              R$/l
# 3  Produto 3                           162              R$/l
# 4  Produto 4                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# ...

# %%
print(produto_view) # não funcionou a referência aqui no vscode
print('\n')
print(produto_copy_bkp)
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object
#
#
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
# voltando para os produtos originais
data['PRODUTO'] = produto_copy_bkp

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
#
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma *lista/Series* de valores ou uma constante a uma **nova chave** do data frame.
#
# **PS**: A *quantidade de valores* da lista precisa ser **igual** ao *número de linhas/registros* do data frame.

# %%
# criando uma coluna a partir de um valor constante/default
# todas as linhas terão o mesmo valor para esta nova coluna
data['coluna sem nocao'] = 'DEFAULT'
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data['coluna a partir de lista'] = range(data.shape[0])

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# ...

# %%
# não funciona pois a quantidade de elementos da lista (a serem atribuídos à nova coluna) é diferente
# da quantidade de linhas do dataframe
data['nao funciona'] = [1, 2, 3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ariel.asilva2\Documents\GitHub\Learning-Pandas\Aulas #03 a #25 - Manipulação de dados com pandas.ipynb Cell 76 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/ariel.asilva2/Documents/GitHub/Learning-Pandas/Aulas%20%2303%20a%20%2325%20-%20Manipula%C3%A7%C3%A3o%20de%20dados%20com%20pandas.ipynb#Y135sZmlsZQ%3D%3D?line=0'>1</a> # não funciona pois a quantidade de elementos da lista (a serem atribuídos à nova coluna) é diferente
#       <a href='vscode-notebook-cell:/c%3A/Users/ariel.asilva2/Documents/GitHub/Learning-Pandas/Aulas%20%2303%20a%20%2325%20-%20Manipula%C3%A7%C3%A3o%20de%20dados%20com%20pandas.ipynb#Y135sZmlsZQ%3D%3D?line=1'>2</a> # da quantidade de linhas do dataframe
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# ...

# %%
data['PREÇO MÉDIO REVENDA (dólares)'] = data['PREÇO MÉDIO REVENDA'] / 5.0

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %% [markdown]
# **PS**: Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerada uma taxa de câmbio fixa, uma vez que cada preço foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 índices
#
# Todo Data Frame possui **índices**, que não são considerados colunas da tabela. Tais índices são comumente **numéricos**, de 0  a num_linhas - 1, mas também podem ser **textuais(rótulos/labels)**

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %% [markdown]
# use `list(data.index)` ou `data.index.to list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com índices Textuais (labels)**

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'NintendoSwitch'])

# %%
pesquisa_de_satisfacao
# Out:
#                 bom  ruim  pessimo
# XboxOne          50   131       30
# Playstation4     21     2       20
# NintendoSwitch  100    30        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation4', 'NintendoSwitch'], dtype='object')

# %%
print(list(pesquisa_de_satisfacao.index))
# Out:
# ['XboxOne', 'Playstation4', 'NintendoSwitch']

# %%
print(pesquisa_de_satisfacao.index.to_list())
# Out:
# ['XboxOne', 'Playstation4', 'NintendoSwitch']

# %% [markdown]
# ### 1.4 Selecionando uma ou mais observações (Indexação)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %% [markdown]
# **==> Index-based selection (seleção baseada em índices)**
#
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do DataFrame, baseado em seu **índice (número)** --> row-first, column-second
#
# **Selecionando um registro/observação/linha**

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %% [markdown]
# **Selecionando múltiplos registros/observações/linhas**

# %%
# selecionando as linhas de índice de 0 a 5 (incluso)
data.iloc[:6]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# ...

# %%
# selecionando os registros/linhas de índice de 10 a 15 (incluso)
data.iloc[10:16]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 10          10   2004-05-09  2004-05-15  NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15  NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15     NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15     NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15     NORTE             AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 10  ETANOL HIDRATADO                            89              R$/l
# 11  ETANOL HIDRATADO                           131              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 13  ETANOL HIDRATADO                            33              R$/l
# 14  ETANOL HIDRATADO                            15              R$/l
# ...

# %%
# selecionando os registros/linhas/observações de índice 1, 5, 10, 15
data.iloc[[1, 5, 10, 15]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 1.162                  0.114  ...                     0.763
# 5                 1.383                  0.132  ...                     0.957
# ...

# %%
# selecionando os registros/linhas/observações de índices 5, 1, 15, 10
data.iloc[[5, 1, 15, 10]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5   ETANOL HIDRATADO                           408              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                 1.383                  0.132  ...                     0.957
# 1                 1.162                  0.114  ...                     0.763
# ...

# %%
# retornar o valor da linha de índice 1, coluna 4 ('ESTADO')
data.iloc[1, 4]
# Out:
# 'GOIAS'

# %% [markdown]
# **==> Label-based selection (seleção baseada em Rótulos)**
# `loc`: seleciona elementos do DataFrame, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#                 bom  ruim  pessimo
# XboxOne          50   131       30
# Playstation4     21     2       20
# NintendoSwitch  100    30        1

# %%
# retorna a linha de índice 0 (implícito) ==> usando o iloc
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# retorna a linha de índice 0 (implícito) e coluna de índice 1 (implícito) ==> usando o iloc
pesquisa_de_satisfacao.iloc[0, 1]
# Out:
# 131

# %%
# retorna a linha cujo o rótulo do índice é 'XboxOne'
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# NÃO FUNCIONA ==> iloc tentando acessar índices com rótulo
pesquisa_de_satisfacao.iloc['XboxOne']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ariel.asilva2\Documents\GitHub\Learning-Pandas\Aulas #03 a #25 - Manipulação de dados com pandas.ipynb Cell 106 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/ariel.asilva2/Documents/GitHub/Learning-Pandas/Aulas%20%2303%20a%20%2325%20-%20Manipula%C3%A7%C3%A3o%20de%20dados%20com%20pandas.ipynb#Y210sZmlsZQ%3D%3D?line=0'>1</a> # NÃO FUNCIONA ==> iloc tentando acessar índices com rótulo
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ariel.asilva2/Documents/GitHub/Learning-Pandas/Aulas%20%2303%20a%20%2325%20-%20Manipula%C3%A7%C3%A3o%20de%20dados%20com%20pandas.ipynb#Y210sZmlsZQ%3D%3D?line=1'>2</a> pesquisa_de_satisfacao.iloc['XboxOne']
#
# File c:\Users\ariel.asilva2\source\repos\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
# ...

# %%
# NÃO FUNCIONA ==> loc tentando acessar índices rotulados com números
pesquisa_de_satisfacao.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ariel.asilva2\source\repos\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# retorna o valor da linha 'Playstation4', coluna 'ruim'
pesquisa_de_satisfacao.loc['Playstation4', 'ruim']
# Out:
# 2

# %%
# selecionando as linhas de índices rotulados 'XboxOne', 'Switch'
pesquisa_de_satisfacao.loc[['XboxOne', 'NintendoSwitch']]
# Out:
#                 bom  ruim  pessimo
# XboxOne          50   131       30
# NintendoSwitch  100    30        1

# %%
# retorna todas as linhas e apenas as colunas com rótulos 'bom' e 'pessimo'
pesquisa_de_satisfacao[['bom', 'pessimo']]
# Out:
#                 bom  pessimo
# XboxOne          50       30
# Playstation4     21       20
# NintendoSwitch  100        1

# %%
# retorna todas as linhas e apenas as colunas com rótulos 'bom' e 'pessimo'
pesquisa_de_satisfacao.loc[:, ['bom', 'pessimo']]
# Out:
#                 bom  pessimo
# XboxOne          50       30
# Playstation4     21       20
# NintendoSwitch  100        1

# %% [markdown]
# ### OBSERVAÇÃO
#
# **Índices numéricos**, por default, possuem **rótulos que correspondem aos seus valores numéricos**.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %%
data.loc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %% [markdown]
# ## 1.5 Selecionando um ou mais atributos (colunas)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
# retornando a coluna/atributo 'ESTADO'
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.loc[:, 'ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# a forma de acesso de colunas por .NOME_DA_COLUNA só funciona se
# NOME_DA_COLUNA não possuir caracteres inválidos (espaços, acentos, cedilha, ...)
### não funciona

data.DATA INICIAL
# Out:
#   Cell In[87], line 5
#     data.DATA INICIAL
#               ^
# SyntaxError: invalid syntax

# %%
# para colunas cujos rótulos possuem caracteres inválidos, apenas
# a seleção via string é válida
data['DATA INICIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 106818    2019-06-23
# 106819    2019-06-23
# 106820    2019-06-23
# 106821    2019-06-23
# 106822    2019-06-23
# Name: DATA INICIAL, Length: 106823, dtype: object

# %%
# selecionando múltiplas colunas: 'PRODUTO', 'ESTADO', 'REGIÃO'
data[['PRODUTO', 'ESTADO', 'REGIÃO']]
# Out:
#                  PRODUTO               ESTADO        REGIÃO
# 0       ETANOL HIDRATADO     DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO                GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO          MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO   MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO              ALAGOAS      NORDESTE
# ...                  ...                  ...           ...
# 106818               GNV  RIO GRANDE DO NORTE      NORDESTE
# 106819               GNV    RIO GRANDE DO SUL           SUL
# 106820               GNV       SANTA CATARINA           SUL
# 106821               GNV            SAO PAULO       SUDESTE
# 106822               GNV              SERGIPE      NORDESTE
#
# [106823 rows x 3 columns]

# %% [markdown]
# ## 1.6 Removendo um Atributo (Coluna) do Data Frame
#
# Como vimos anteriormente, o atributo 'Unnamed: 0' parece ser um **ruído** em nosso dataset. Desta maneira, vamos eliminá-lo.

# %%
data.head(2)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO            ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# ...

# %%
# deleta/remove in-place (ou seja, no próprio dataframe) a coluna de rótulo 'Unnamed: 0'
del data['Unnamed: 0']

# %%
data.head(2)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                  0.016                  1.19  ...                     0.825
# 1                  0.114                  0.89  ...                     0.763
#
#   DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                     0.4201
# 1                      0.088                     0.5013
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# ...

# %% [markdown]
# Vamos agora remover as colunas fictícias criadas nos vídeos para estudo.

# %%
del data['coluna sem nocao']
del data['coluna a partir de lista']
del data['PREÇO MÉDIO REVENDA (dólares)']

# %%
data.head(2)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# ...

# %% [markdown]
# ## 1.7 Salvando um Data Frame
#
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `to_csv`.
#
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.
#
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).
#
# Desta forma, utilize o parâmetro: `index=False`
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
data.to_csv('./datasets/GasPricesinBrazil_2004-2019 Pré Processado.csv', index=False, sep=';')

# %% [markdown]
# ## Seleção Condicional: Filtrando amostras
#
# Durante nossa nálise exploratória, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica.
#
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nossos dataset pré-processado que salvamos no item anterior.

# %%
data = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019 Pré Processado.csv', sep=';')

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
# Mostra todos os estados ccujos os preços dos combustíveis foram aferidos
# Mais tecnicamente, mostra os valores únicos presentes para o atributo/coluna 'ESTADO'
data['ESTADO'].unique() # .unique() => tira as repetições e mostra os valores únicos
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %% [markdown]
# **Selecionando apenas os preços dos postos de São Paulo**
#
# **==> Alternativa 1: Seleção Condicional (Comparações diretas)**
#
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (observações) do Data Frame, que informa os registros de preços dos postos do estado de São Paulo (True).

# %%
# faz uma comparação elemento a elemento da series, retornando uma series de booleans
data['ESTADO'] == 'SAO PAULO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
# salvando essa series de booleans em uma variável
selecao = data['ESTADO'] == 'SAO PAULO'

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
type(selecao)
# Out:
# pandas.core.series.Series

# %%
selecao.shape
# Out:
# (106823,)

# %%
data.shape
# Out:
# (106823, 20)

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado de São Paulo:

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# O resultado é um Data Frame (novo) com apenas os registros desejados após a **filtragem**.
#
# Podemos ainda utilizar o método loc para o mesmo afim:

# %%
data.loc[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# **==> Alternativa 2: utilizando o método `query`**
#
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
data.query('ESTADO == "SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análises feitas para os postos de São Paulo (neste caso).

# %%
postos_sp = data.query('ESTADO == "SAO PAULO"')

# %%
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
type(postos_sp)
# Out:
# pandas.core.frame.DataFrame

# %%
postos_sp.shape
# Out:
# (4263, 20)

# %%
postos_sp.head()
# Out:
#     DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23    2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50    2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77    2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                           4047              R$/l                0.768
# 50                           4066              R$/l                0.766
# 77                           4077              R$/l                0.823
# 104                          4073              R$/l                0.887
# 131                          4082              R$/l                0.894
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# ### Resetando os índices
#
# Note que os *índices das linhas/registros* após a filtragem **continuam sendo os mesmos** do DataFrame original.
#
# Em muitas situações, manter esta informação será importante.
#
# Mas se você quiser **resetar os índices** do data frame filtrado fazendo com que os registros comecem com *[indice 0 até num_linhas-1*, use o método `.reset_index`.

# %%
postos_sp.reset_index(drop=True)
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %%
# ainda não foi alterado, precisamos usar o atributo/parâmetro inplace=True
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
postos_sp.reset_index(drop=True, inplace=True)

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %%
# ALTERNATIVA MUITO COMUM
postos_sp = data.query('ESTADO == "SAO PAULO"').reset_index(drop=True) # não precisa passar o inplace=True

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %% [markdown]
# ### **Selecionando registros de postos do Rio de Janeiro com preços acima de 2 reais**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
data['ESTADO'] == 'RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
data['PREÇO MÉDIO REVENDA'] > 2.0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818     True
# 106819     True
# 106820     True
# 106821     True
# 106822     True
# Name: PREÇO MÉDIO REVENDA, Length: 106823, dtype: bool

# %%
selecao = (data['ESTADO'] == 'RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA'] > 2.0)
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %% [markdown]
# Note que o resultado da seleção continua sendo uma *Series de booleans* com o *mesmo número de linhas/amostra do DataFrame*, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro **E** o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&).
#
# Similarmente:
#
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
data.query('ESTADO == "RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:3526 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[125], line 2
#     data.query('ESTADO == "RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')
#
#   File c:\Users\ariel.asilva2\source\repos\Lib\site-packages\pandas\core\frame.py:4602 in query
#     res = self.eval(expr, **kwargs)
#
#   File c:\Users\ariel.asilva2\source\repos\Lib\site-packages\pandas\core\frame.py:4728 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File c:\Users\ariel.asilva2\source\repos\Lib\site-packages\pandas\core\computation\eval.py:336 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File c:\Users\ariel.asilva2\source\repos\Lib\site-packages\pandas\core\computation\expr.py:808 in __init__
#     self.terms = self.parse()
#
# ...

# %%
# funciona, pois não tem caractere inválido para o método .query()
data.query('ESTADO == "RIO DE JANEIRO" or ESTADO == "SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
# ...

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (observação a observação) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde *apenas* a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2.0)` checa,  linha a linha (observação a observação) do DataFrame, quais são os registros cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde *apenas* a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.
#
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. O Pandas tenta otimizar isso ao máximo por de trás dos panos. Mas, de fato, se tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará *lenta*.
#
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
selecao_1 = data['ESTADO'] == 'RIO DE JANEIRO'
postos_rj = data[selecao_1]
postos_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 103      2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 130      2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %%
selecao_2 = postos_rj['PREÇO MÉDIO REVENDA'] > 2
selecao_2
# Out:
# 22        False
# 49        False
# 76        False
# 103       False
# 130       False
#           ...
# 106718     True
# 106745     True
# 106772     True
# 106799     True
# 106817     True
# Name: PREÇO MÉDIO REVENDA, Length: 4263, dtype: bool

# %%
postos_rj_preco_maior_que_2 = postos_rj[selecao_2]
postos_rj_preco_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %% [markdown]
# Ou seja:

# %%
selecao_1 = data['ESTADO'] == 'RIO DE JANEIRO'
postos_rj = data[selecao_1]

selecao_2 = postos_rj['PREÇO MÉDIO REVENDA'] > 2
postos_rj_preco_maior_que_2 = postos_rj[selecao_2]

postos_rj_preco_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %% [markdown]
# É mais eficiente do que:

# %%
selecao = (data['ESTADO'] == 'RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA'] > 2.0)

data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %% [markdown]
# Pois há uma seleção em cima de outra seleção, evitando comparações inúteis desnecessariamente.

# %% [markdown]
# ### **Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais**
#
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro *múltiplas vezes*

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
selecao_2 = (data['PRODUTO'] == 'GASOLINA COMUM')
selecao_3 = (data['PREÇO MÉDIO REVENDA'] > 2)

selecao_final = selecao_1 & selecao_2 & selecao_3

selecao_final
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %%
data_filtrado = data[selecao_final]
data_filtrado
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
print(data_filtrado['ESTADO'].unique())
print(data_filtrado['PRODUTO'].unique())
# Out:
# ['RIO DE JANEIRO' 'SAO PAULO']
# ['GASOLINA COMUM']

# %% [markdown]
# Alternativadamente (maneira mais eficiente)

# %%
# apenas registros de postos dos estados de SP e RJ
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')

postos_sp_rj = data[selecao_1]

# apenas registros de postos dos estados de SP e RJ cujo produto é GASOLINA COMUM
selecao_2 = (postos_sp_rj['PRODUTO'] == 'GASOLINA COMUM')

postos_sp_rj_gasolina = postos_sp_rj[selecao_2]

# apenas registros de postos dos estados de SP e RJ cujo produto é GASOLINA COMUM e cujo PREÇO MÉDIO REVENDA é maior que 2
selecao_3 = (postos_sp_rj_gasolina['PREÇO MÉDIO REVENDA'] > 2)

postos_sp_rj_gasolina_preco_maior_que_2 = postos_sp_rj_gasolina[selecao_3]

# %%
postos_sp_rj_gasolina_preco_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# ### **Selecionando os registros dos anos de 2008, 2010 e 2012**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# **ALTERNATIVA 1**

# %%
selecao = (data['ANO'] == 2008) | (data['ANO'] == 2010) | (data['ANO'] == 2012)
data[selecao]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# **ALTERNATIVA 2**

# %%
lista_de_anos = [2008, 2010, 2012]

# %%
selecao = data['ANO'].isin(lista_de_anos) # retorna uma series de booleanos
data[selecao]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# **ALTERNATIVA 3**

# %%
lista_de_anos
# Out:
# [2008, 2010, 2012]

# %%
data.query('ANO in @lista_de_anos') # @ => serve para colocar variáveis na query
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# ### **Iterando com DataFrames**
#
# For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjuntos de dados)

# %%
data.head(10)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# ...

# %%
for index, row in data.head(10).iterrows():
    print(f'índice {index} ==> {row}')
# Out:
# índice 0 ==> DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                           DISTRITO FEDERAL
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  127
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.288
# DESVIO PADRÃO REVENDA                       0.016
# PREÇO MÍNIMO REVENDA                         1.19
# PREÇO MÁXIMO REVENDA                         1.35
# MARGEM MÉDIA REVENDA                        0.463
# COEF DE VARIAÇÃO REVENDA                    0.012
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.825
# DESVIO PADRÃO DISTRIBUIÇÃO                   0.11
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.4201
# PREÇO MÁXIMO DISTRIBUIÇÃO                  0.9666
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.133
# ...

# %%
for index, row in data.head(10).iterrows():
    print(f'índice {index} ==> {row["ESTADO"]}')
# Out:
# índice 0 ==> DISTRITO FEDERAL
# índice 1 ==> GOIAS
# índice 2 ==> MATO GROSSO
# índice 3 ==> MATO GROSSO DO SUL
# índice 4 ==> ALAGOAS
# índice 5 ==> BAHIA
# índice 6 ==> CEARA
# índice 7 ==> MARANHAO
# índice 8 ==> PARAIBA
# índice 9 ==> PERNAMBUCO

# %% [markdown]
# # 2. Preparação dos dados
#
# ---

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ## 2.1 Removendo amostras com valores vazios (null/nan) no dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  object
#  1   DATA FINAL                     106823 non-null  object
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
# ...

# %% [markdown]
# De um total de 106823 observações, **não há valores null / nan** para nenhum atributo. Mas, veremos que não é bem assim nesse caso específico.

# %% [markdown]
# ## 2.2 Conversão de tipos de atributos
#
# O pandas automaticamente reconhece os tipos de dados de cada coluna.
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex, "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser `float64` e não `object`.
# Nestes casos, muito provavelmente alguns registros têm uma string ao invés de um número para tais atributos.
#
# Os atributos "DATA INICIAL" e "DATA FINAL" deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são `objects`, mas poderiam ser o tipo `category`, que é um tipo especial do pandas.
# Este tipo é necessário para se utilizar algumas funções específicas do pandas.
# **Não** converteremos para este tipo por ora.

# %%
data_pre = data.copy()

# %% [markdown]
# **Datas**
#
# Como os atributos de data do dataset já estão em um formato aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %% [markdown]
# **DADOS NUMÉRICOS**

# %%
# convertendo atributos/colunas para 'numeric'
for atributo in ['MARGEM MÉDIA REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO', 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
    # converte a coluna (de valores string) para um tipo numérico
    # em caso de erro na conversão (p. ex., uma string que não representa um número), um valor vazio (null / nan)
    # será atribuído no lugar
    data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors='coerce')

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %% [markdown]
# Note que temos vários valores **null** agora **após a conversão de tipos**. Vamos checá-los com mais cuidado nos dados originais e pré processados.

# %% [markdown]
# ## 2.3 Limpeza de dados

# %%
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()

# %%
data_pre[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
# nos dados originais, quais eram os valores do PREÇO MÉDIO DISTRIBUIÇÃO dos registros que agora possuem valores NaN
data[mask]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25  2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09  2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23  2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26  2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27  2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106664   2019-06-16  2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16  2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23  2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23  2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23  2019-06-29      SUL          PARANA               GNV
#
# ...

# %% [markdown]
# Várias amostras possuem a string '-' em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras.

# %% [markdown]
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %%
# retorna uma cópia do data frame 'data_pre' com todos os valores NaN de todas as colunas agora preenchidos com 0.
# para alterar o próprio data frame, use o argumento 'inplace=True'.
data_pre_fill = data_pre.fillna(0)
data_pre_fill[mask] # valores que antes eram NaN agora são 0.
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
# retorna uma cópia do data frame 'data_pre' com todos os valores NaN das colunas:
# 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO' E 'PREÇO MÁXIMO DISTRIBUIÇÃO', respectivamente, com 
data_pre_fill = data_pre.fillna(value={
    'PREÇO MÉDIO DISTRIBUIÇÃO': 10,
    'DESVIO PADRÃO DISTRIBUIÇÃO': 20,
    'PREÇO MÍNIMO DISTRIBUIÇÃO': 30,
    'PREÇO MÁXIMO DISTRIBUIÇÃO': 'vazio'
})
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex.: o '**PREÇO MÉDIO DISTRIBUIÇÃO**'.
#
# A fim de não termos valores sintéticos gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas.
#
# Para isso, basta utilizarmos o método `dropna`

# %%
# remove no próprio dataframe, todas as linhas/registros com valores NaN (vazios) em quaisquer colunas/atributos
data_pre.dropna(inplace=True)

data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103392 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  datetime64[ns]
#  1   DATA FINAL                     103392 non-null  datetime64[ns]
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
# ...

# %% [markdown]
# Nosso data frame agora, após essa limpeza, ficou mais enxuto, contendo 103392 registros frente aos 106823 registros originais.
#
# Essas são apenas algumas das possíveis técnicas de limpeza de dados. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# ### Salvando Dataset Preprocessado

# %%
data_pre.to_csv('./datasets/GasPricesinBrazil_2004-2019 Pré Processado FINAL.csv', index=False)

# %% [markdown]
# # 3. Estatísticas Descritivas
# ---

# %%
data_final = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019 Pré Processado FINAL.csv')

# %%
data_final
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# O Pandas fornece algumas funções/métodos que computam certas estatísticas descritivas.
#
# `describe`: exibe várias **estatísticas descritivas** para os atributos de um dataframe ou para uma *Series*.

# %%
data_final.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# ...

# %% [markdown]
# Como o resultado do `describe` de um *dataframe*, podemos filtrar apenas algumas colunas.

# %%
data_final.describe()['PREÇO MÉDIO REVENDA']
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
# 2° maneira
data_final['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats = data_final.describe()

stats[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %%
# 2° maneira (tende a ser mais rápido, pois filtra primeiro e computa depois)
data_final[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %%
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# ...

# %%
stats.loc[['min', 'max', 'mean']]
# Out:
#       NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# min                       1.000000             0.766000
# max                    4167.000000            99.357000
# mean                    240.511935            10.784472
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# min                0.000000              0.590000              0.999000
# max               10.748000             90.000000            120.000000
# mean               0.652589              9.334931             12.458686
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# min               0.001000                  0.000000
# max              36.847000                  0.262000
# mean              2.225151                  0.045749
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# min                   0.506000                    0.000000
# max                  83.137000                   18.385000
# ...

# %%
stats.loc[['min', 'max', 'mean'], 'PREÇO MÉDIO REVENDA']
# Out:
# min      0.766000
# max     99.357000
# mean    10.784472
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats.loc[['min', 'max', 'mean'], ['PREÇO MÉDIO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#       PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# min              0.766000                  0.506000
# max             99.357000                 83.137000
# mean            10.784472                  8.559322

# %% [markdown]
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# Qual é o menor preço mínimo de revenda?

# %%
data_final['PREÇO MÍNIMO REVENDA'].min()
# Out:
# 0.59

# %% [markdown]
# Qual é a média e desvio padrão dos preços mínimos de revenda?

# %%
mean = data_final['PREÇO MÍNIMO REVENDA'].mean()
std = data_final['PREÇO MÍNIMO REVENDA'].std()

print(f'A média dos preços mínimos de revenda é {mean:.2f} +- {std:.2f}')
# Out:
# A média dos preços mínimos de revenda é 9.33 +- 15.02

# %% [markdown]
# Quais são os estados considerados?

# %%
data_final['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 103387    RIO GRANDE DO NORTE
# 103388      RIO GRANDE DO SUL
# 103389         SANTA CATARINA
# 103390              SAO PAULO
# 103391                SERGIPE
# Name: ESTADO, Length: 103392, dtype: object

# %%
data_final['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
sorted(data_final['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %% [markdown]
# Quantos registros (aferições) cada estado possui?
#
# `.value_counts()`: conta a frequência dos valores de uma dada variável (de preferência, *categórica*)

# %%
data_final['ESTADO'].value_counts() # retorna em ordem decrescente, a quantidade de registros/linhas para cada estado
# Out:
# ESTADO
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996
# Name: count, dtype: int64

# %%
data_final['ESTADO'].value_counts().to_frame() # converte uma Series para um dataframe
# Out:
#                      count
# ESTADO
# BAHIA                 4263
# RIO DE JANEIRO        4262
# SAO PAULO             4261
# RIO GRANDE DO SUL     4249
# PARAIBA               4240
# PERNAMBUCO            4236
# SERGIPE               4202
# SANTA CATARINA        4164
# MINAS GERAIS          4142
# ESPIRITO SANTO        4079
# MATO GROSSO DO SUL    4076
# ALAGOAS               4020
# RIO GRANDE DO NORTE   3999
# CEARA                 3964
# PARANA                3902
# AMAZONAS              3713
# MATO GROSSO           3703
# PARA                  3477
# MARANHAO              3470
# ACRE                  3463
# RORAIMA               3457
# TOCANTINS             3453
# GOIAS                 3449
# RONDONIA              3441
# PIAUI                 3394
# DISTRITO FEDERAL      3317
# AMAPA                 2996

# %% [markdown]
# # 4. Executando funções para cada item de um DataFrame ou Series
# ---
#
# Uma alternativa ao `for-loop` que vimos anteriormente e que é *lento*, é usarmos funções próprias do *pandas* que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".
#
# ![image.png](attachment:image.png)
#
# Fonte: https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                    index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# `apply()`: usado par aplicar uma função ao longo de um eixo (axis) de um DataFrame ou em valores de uma Series.
#
# ![image.png](attachment:image.png)
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %%
def nossa_soma(series):
    return series.sum() # retorna a soma de todos os valores de uma linha

# %%
df['SOMA (A, B, C)'] = df.apply(nossa_soma, axis=1)

df
# Out:
#          A   B    C  SOMA (A, B, C)
# Linha 1  1  10  100             111
# Linha 2  2  20  200             222
# Linha 3  3  30  300             333
# Linha 4  4  40  400             444

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# usa-se o loc para gerar índices novos
df.loc['Linha 5'] = df.apply(nossa_soma, axis=0)

df
# Out:
#           A    B     C  SOMA (A, B, C)
# Linha 1   1   10   100             111
# Linha 2   2   20   200             222
# Linha 3   3   30   300             333
# Linha 4   4   40   400             444
# Linha 5  10  100  1000            1110

# %% [markdown]
# Usando `lambda` functions (função temporária)

# %%
df['MEDIA(A, B, C)'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)

df
# Out:
#           A    B     C  SOMA (A, B, C)  MEDIA(A, B, C)
# Linha 1   1   10   100             111            37.0
# Linha 2   2   20   200             222            74.0
# Linha 3   3   30   300             333           111.0
# Linha 4   4   40   400             444           148.0
# Linha 5  10  100  1000            1110           370.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# aplica a lambda function abaixo para cada elemento da coluna
df ['C * 2'] = df['C'].apply(lambda x: x * 2)

df
# Out:
#           A    B     C  SOMA (A, B, C)  MEDIA(A, B, C)  C * 2
# Linha 1   1   10   100             111            37.0    200
# Linha 2   2   20   200             222            74.0    400
# Linha 3   3   30   300             333           111.0    600
# Linha 4   4   40   400             444           148.0    800
# Linha 5  10  100  1000            1110           370.0   2000

# %%
df['A * 2'] = df['A'] * 2

df
# Out:
#           A    B     C  SOMA (A, B, C)  MEDIA(A, B, C)  C * 2  A * 2
# Linha 1   1   10   100             111            37.0    200      2
# Linha 2   2   20   200             222            74.0    400      4
# Linha 3   3   30   300             333           111.0    600      6
# Linha 4   4   40   400             444           148.0    800      8
# Linha 5  10  100  1000            1110           370.0   2000     20

# %% [markdown]
# `applymap()`: usado para aplicar uma função para **cada elemento** (*element-wise*) de um DataFrame.

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                    index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
# retorna um novo dataframe com todos os elementos ao quadrado.
# poderíamos usar uma função ao invés de uma lambda function
df.applymap(lambda x: x ** 2)
# Out:
# C:\Users\ariel.asilva2\AppData\Local\Temp\ipykernel_20988\3314123372.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x ** 2)
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %%
df # não foi alterado
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# `map()`: usado para aplicar uma função para **cada elemento** (*element-wise*) de uma Series.

# %%
nomes = pd.Series(['João', 'Maria', 'Alice', 'Pedro'])
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: object

# %%
# retorna uma nova Series com todos os nomes com letras maiúsculas.
# poderíamos usar uma função ao invés de uma lambda function
nomes.map(lambda x: x.upper())
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: object

# %%
# O Pandas já fornece uma série de métodos para manipulação de strings.
# Assim, poderíamos usar o código abaixo para obter o mesmo resultado.
nomes.str.upper()
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: object
