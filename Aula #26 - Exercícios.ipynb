# %% [markdown]
# # 7. Exercícios
# ---
# Vamos aplicar os conceitos que vimos em alguns exercícios.
# Para isso, utilizaremos o dataset de preços de combustíveis no Brasil.

# %%
import pandas as pd

data = pd.read_csv("./datasets/GasPricesinBrazil_2004-2019 Pré Processado FINAL.csv", sep=',')
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103392 entries, 0 to 103391
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  object
#  1   DATA FINAL                     103392 non-null  object
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
# ...

# %% [markdown]
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover** os dados deste ano da análise.

# %%
# Criando lista com índices que constam o ano como 2019
dados_2019 = list((data.query('ANO == 2019')).index)
dados_2019

# criando um novo dataframe com os índices de 2019 eliminados
df = data.drop(dados_2019)
df
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# ...

# %%
# 2° maneira: filtragem, e não drop.
df = data.query("ANO != 2019")
df
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# Note que temos um novo dataframe com 99739 linhas, mas com índices fora desse intervalo.
# Acontece que os registros mantiveram seus índices originais após a query.
#
# Para resetar os índices de 0 a *num_linhas-1*, basta usarmos o método `.reset_index()`.

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# Os índices agora foram **resetados**. Porém, os índices antigos se transformaram em *uma nova coluna* chamada 'index'.
# Para removê-la durante o *reset*, basta passarmos o argumento `drop=True`.

# %% [markdown]
# ## 7.1 (exercício diferente) Qual a quantidade de cada produto em cada região?

# %%
grupo = df.groupby(['PRODUTO', 'REGIÃO'])
resultado = grupo['REGIÃO'].value_counts().to_frame()
resultado
# Out:
#                                count
# PRODUTO          REGIÃO
# ETANOL HIDRATADO CENTRO OESTE   3022
#                  NORDESTE       6821
#                  NORTE          5021
#                  SUDESTE        3039
#                  SUL            2278
# GASOLINA COMUM   CENTRO OESTE   3034
#                  NORDESTE       6838
#                  NORTE          5289
#                  SUDESTE        3040
#                  SUL            2279
# GLP              CENTRO OESTE   2998
#                  NORDESTE       6185
#                  NORTE          5152
#                  SUDESTE        3037
#                  SUL            2268
# GNV              CENTRO OESTE    825
#                  NORDESTE       5030
#                  NORTE           233
#                  SUDESTE        2772
#                  SUL            1847
# ÓLEO DIESEL      CENTRO OESTE   3034
#                  NORDESTE       6836
#                  NORTE          5290
# ...

# %% [markdown]
# ## 7.1 Qual a proporção de postos pesquisados para cada combustível em cada região?

# %% [markdown]
# Nota: tenho que calcular a quantidade de postos pesquisados para cada combustível em cada região.

# %%
grupo = df.groupby(['PRODUTO', 'REGIÃO'])
grupo.groups
# Out:
# {('ETANOL HIDRATADO', 'CENTRO OESTE'): [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], ('ETANOL HIDRATADO', 'NORDESTE'): [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279,
# ...

# %%
resultado = grupo['NÚMERO DE POSTOS PESQUISADOS'].sum().to_frame()
resultado
# Out:
#                                NÚMERO DE POSTOS PESQUISADOS
# PRODUTO          REGIÃO
# ETANOL HIDRATADO CENTRO OESTE                        472434
#                  NORDESTE                           1061049
#                  NORTE                               242562
#                  SUDESTE                            3190178
#                  SUL                                1052410
# GASOLINA COMUM   CENTRO OESTE                        474131
#                  NORDESTE                           1200306
#                  NORTE                               415673
#                  SUDESTE                            3233991
#                  SUL                                1143045
# GLP              CENTRO OESTE                        614634
#                  NORDESTE                            797187
#                  NORTE                               478249
#                  SUDESTE                            2328664
# ...

# %% [markdown]
# ## 7.2 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %%
df_sp = df.query('ESTADO == "SAO PAULO"')
df_sp_gasolina = df_sp.query('PRODUTO == "GASOLINA COMUM"')
df_sp_gasolina_2018 = df_sp_gasolina.query('ANO == 2018')
df_sp_gasolina_2018.head()
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92610   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92755   2018-01-28  2018-02-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92901   2018-02-04  2018-02-10  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92319                          1641              R$/l                3.988
# 92465                          1648              R$/l                4.002
# 92610                          1648              R$/l                4.006
# 92755                          1644              R$/l                4.019
# 92901                          1646              R$/l                4.004
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# ## Estatísticas Descritivas

# %%
df_sp_gasolina_2018.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                     52.000000            52.000000
# mean                    1610.211538             4.202769
# std                      213.627432             0.180672
# min                      102.000000             3.970000
# 25%                     1639.000000             4.008000
# 50%                     1642.000000             4.202000
# 75%                     1644.000000             4.336250
# max                     1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# min                 0.150000              3.369000              4.499000
# 25%                 0.159750              3.499000              4.899000
# ...

# %%
df_sp_gasolina_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %% [markdown]
# ## 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
df2_sp = df.query('ESTADO == "SAO PAULO"')
df2_sp_gasolina_e_etanol = df2_sp.query('PRODUTO == "GASOLINA COMUM" or PRODUTO == "ETANOL HIDRATADO"')
df2_sp_gasolina_e_etanol_2018 = df2_sp_gasolina_e_etanol.query('ANO == 2018')
df2_sp_gasolina_e_etanol_2018.head()
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92238                          1664              R$/l                2.833
# 92319                          1641              R$/l                3.988
# 92384                          1661              R$/l                2.868
# 92465                          1648              R$/l                4.002
# 92529                          1662              R$/l                2.874
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %%
df2_sp_gasolina_e_etanol_2018.shape
# Out:
# (104, 20)

# %%
df2_sp_gasolina_e_etanol_2018.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                    104.000000           104.000000
# mean                    1620.557692             3.457337
# std                      213.422086             0.766239
# min                      102.000000             2.393000
# 25%                     1641.000000             2.726000
# 50%                     1647.000000             3.431000
# 75%                     1662.000000             4.199000
# max                     1665.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count             104.000000            104.000000            104.000000
# mean                0.167760              2.958663              4.318058
# std                 0.021546              0.736680              0.681788
# min                 0.133000              1.895000              3.199000
# 25%                 0.150750              2.259000              3.699000
# ...

# %%
df2_sp_gasolina_e_etanol_2018[['PREÇO MÉDIO REVENDA', 'PREÇO MÍNIMO REVENDA', 'PREÇO MÁXIMO REVENDA']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA
# count           104.000000            104.000000            104.000000
# mean              3.457337              2.958663              4.318058
# std               0.766239              0.736680              0.681788
# min               2.393000              1.895000              3.199000
# 25%               2.726000              2.259000              3.699000
# 50%               3.431000              2.919000              4.244500
# 75%               4.199000              3.679000              4.999000
# max               4.512000              3.969000              5.299000

# %% [markdown]
# Outra forma de fazer:

# %%
resultado = df.query('(PRODUTO == "GASOLINA COMUM" or PRODUTO == "ETANOL HIDRATADO") and ESTADO == "SAO PAULO" and ANO == 2018')

# 2° forma (com lista)
resultado = df.query('(PRODUTO in ["GASOLINA COMUM", "ETANOL HIDRATADO"]) and ESTADO == "SAO PAULO" and ANO == 2018')

# %%
resultado.shape
# Out:
# (104, 20)

# %%
resultado.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                    104.000000           104.000000
# mean                    1620.557692             3.457337
# std                      213.422086             0.766239
# min                      102.000000             2.393000
# 25%                     1641.000000             2.726000
# 50%                     1647.000000             3.431000
# 75%                     1662.000000             4.199000
# max                     1665.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count             104.000000            104.000000            104.000000
# mean                0.167760              2.958663              4.318058
# std                 0.021546              0.736680              0.681788
# min                 0.133000              1.895000              3.199000
# 25%                 0.150750              2.259000              3.699000
# ...

# %%
resultado[['PREÇO MÉDIO REVENDA', 'PREÇO MÍNIMO REVENDA', 'PREÇO MÁXIMO REVENDA']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA
# count           104.000000            104.000000            104.000000
# mean              3.457337              2.958663              4.318058
# std               0.766239              0.736680              0.681788
# min               2.393000              1.895000              3.199000
# 25%               2.726000              2.259000              3.699000
# 50%               3.431000              2.919000              4.244500
# 75%               4.199000              3.679000              4.999000
# max               4.512000              3.969000              5.299000

# %%
resultado.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                   count      mean       std    min     25%    50%      75%  \
# PRODUTO
# ETANOL HIDRATADO   52.0  2.711904  0.141365  2.393  2.6315  2.720  2.83825
# GASOLINA COMUM     52.0  4.202769  0.180672  3.970  4.0080  4.202  4.33625
#
#                     max
# PRODUTO
# ETANOL HIDRATADO  2.892
# GASOLINA COMUM    4.512
